# %% [markdown]
# # Movie Data Project

# %% [markdown]
# ## Business Understanding
# _I will write stuff here to describe my problem, and my question, and my stakeholder, etc. etc._

# %% [markdown]
# ## Data Understanding
# *Might write a summery of the data I end up using here*

# %%
import pandas as pd
import sqlite3

# %%
# !ls zippedData/
# Out:
# bom.movie_gross.csv.gz  rt.movie_info.tsv.gz    tn.movie_budgets.csv.gz
# im.db                   rt.reviews.tsv.gz
# im.db.zip               tmdb.movies.csv.gz

# %%
tmdb = pd.read_csv('zippedData/tmdb.movies.csv.gz')
tmdb
# Out:
#        Unnamed: 0            genre_ids      id original_language  \
# 0               0      [12, 14, 10751]   12444                en
# 1               1  [14, 12, 16, 10751]   10191                en
# 2               2        [12, 28, 878]   10138                en
# 3               3      [16, 35, 10751]     862                en
# 4               4        [28, 878, 12]   27205                en
# ...           ...                  ...     ...               ...
# 26512       26512             [27, 18]  488143                en
# 26513       26513             [18, 53]  485975                en
# 26514       26514         [14, 28, 12]  381231                en
# 26515       26515      [10751, 12, 28]  366854                en
# 26516       26516             [53, 27]  309885                en
#
#                                      original_title  popularity release_date  \
# 0      Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# ...

# %%
movie_budgets = pd.read_csv('zippedData/tn.movie_budgets.csv.gz')
movie_budgets
# Out:
#       id  release_date                                        movie  \
# 0      1  Dec 18, 2009                                       Avatar
# 1      2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2      3   Jun 7, 2019                                 Dark Phoenix
# 3      4   May 1, 2015                      Avengers: Age of Ultron
# 4      5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# ...   ..           ...                                          ...
# 5777  78  Dec 31, 2018                                       Red 11
# 5778  79   Apr 2, 1999                                    Following
# 5779  80  Jul 13, 2005                Return to the Land of Wonders
# 5780  81  Sep 29, 2015                         A Plague So Pleasant
# 5781  82   Aug 5, 2005                            My Date With Drew
#
#      production_budget domestic_gross worldwide_gross
# 0         $425,000,000   $760,507,625  $2,776,345,279
# ...

# %%
#merged = outcomes.merge(intakes, on= "Animal ID", how ='inner', suffixes=('_outcomes','_intake'))

# %%
#bom_tmdb_merge_inner = pd.merge(bom, tmdb, left_on = 'title', right_on = 'original_title', how= 'inner', suffixes = ('_bom', '_tmdb'), )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [7], in <cell line: 1>()
# ----> 1 bom_tmdb_merge_inner = pd.merge(bom, tmdb, left_on = 'title', right_on = 'original_title', how= 'inner', suffixes = ('_bom', '_tmdb'), )
#
# NameError: name 'bom' is not defined

# %%
#bom_tmdb_merge_inner

# %%
#bom_tmdb_merge_outer = pd.merge(bom, tmdb, left_on = 'title', right_on = 'original_title', how= 'outer', suffixes = ('_bom', '_tmdb'), )

# %%
#bom_tmdb_merge_outer

# %%
tmdb['genre_ids'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0            [12, 14, 10751]
# 1        [14, 12, 16, 10751]
# 2              [12, 28, 878]
# 3            [16, 35, 10751]
# 4              [28, 878, 12]
#                 ...
# 26512               [27, 18]
# 26513               [18, 53]
# 26514           [14, 28, 12]
# 26515        [10751, 12, 28]
# 26516               [53, 27]
# Name: genre_ids, Length: 26517, dtype: object>

# %%
high_vote_subset = tmdb.loc[(tmdb['vote_average']>= 8.0) & (tmdb['vote_count'] > 100)]

# %%
high_vote_subset
# Out:
#        Unnamed: 0       genre_ids      id original_language  \
# 4               4   [28, 878, 12]   27205                en
# 19             19  [18, 53, 9648]   11324                en
# 43             43     [35, 10749]     239                en
# 58             58            [18]     705                en
# 103           103    [28, 18, 36]   11645                ja
# ...           ...             ...     ...               ...
# 24299       24299            [18]   10238                sv
# 24330       24330        [80, 18]   11656                sv
# 24351       24351            [35]  508933                en
# 24403       24403            [18]   12761                sv
# 24435       24435            [35]  529531                en
#
#                 original_title  popularity release_date  \
# 4                    Inception      27.920   2010-07-16
# 19              Shutter Island      18.060   2010-02-18
# 43            Some Like It Hot      14.200   1959-03-18
# ...
